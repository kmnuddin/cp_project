# %%
from MNE_Pipeline import MNE_Repo_Mat
import os

# %%
mp = MNE_Repo_Mat()

info = mp.construct_info()
# Out:
# /home/kam/anaconda3/envs/mne/lib/python3.7/site-packages/mne/utils/docs.py:830: DeprecationWarning: Function read_montage is deprecated; ``read_montage`` is deprecated and will be removed in v0.20. Please use ``read_dig_fif``, ``read_dig_egi``, ``read_custom_montage``, or ``read_dig_captrack`` to read a digitization based on your needs instead; or ``make_standard_montage`` to create ``DigMontage`` based on template; or ``make_dig_montage`` to create a ``DigMontage`` out of np.arrays
#   warnings.warn(msg, category=DeprecationWarning)
# /home/kam/anaconda3/envs/mne/lib/python3.7/site-packages/mne/utils/docs.py:813: DeprecationWarning: Class Montage is deprecated; Montage class is deprecated and will be removed in v0.20. Please use DigMontage instead.
#   warnings.warn(msg, category=DeprecationWarning)
# ...

# %%
subjects = [os.path.splitext(file)[0] for file in os.listdir('Data/') if file.endswith('.mat')]
subjects_path = ['Data/{}'.format(file) for file in os.listdir('Data/') if file.endswith('.mat')]

# %%
for subject, path in zip(subjects, subjects_path):
    mp.load_data(path)
    mp.save_pow_band_topomap_for_st(subject, band='beta', fmin=16, fmax=31)
# Out:
# saved topomap for beta band for S20
# saved topomap for beta band for N5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e1be25e6d875> in <module>
#       1 for subject, path in zip(subjects, subjects_path):
#       2     mp.load_data(path)
# ----> 3     mp.save_pow_band_topomap_for_st(subject, band='beta', fmin=16, fmax=31)
#
# ~/CP Project/MNE_Pipeline.py in save_pow_band_topomap_for_st(self, subject, band, fmin, fmax)
#     219             fig_path = band_path + '/trial_' + str(i+1) + '.png'
#     220
# --> 221             fig.savefig(fig_path, dpi=128)
#     222
#     223         print('saved topomap for {} band for {}'.format(band, subject))
#
# ~/anaconda3/envs/mne/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# ...
